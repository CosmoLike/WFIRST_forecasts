# %%
import numpy as np
import matplotlib.pyplot as plt
from matplotlib.colors import LogNorm#, SymLogNorm
# import matplotlib.image as mpimg
import sys
import math
from numpy import linalg as LA

path='/users/timeifler/CosmoLike/WFIRST_forecasts/datav/'
fig=plt.figure(1)
for i in range(10):
    data = np.genfromtxt(path+"WFIRST_all_2pt_clusterN_clusterWL_test_fid_"+str(i))
    plt.plot(data[0:12,0],data[0:12,1],lw=2)

ax.set_yscale("log", nonposy='clip')
plt.plot
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-19-30253dfc261b> in <module>()
#      12     data = np.genfromtxt(path+"WFIRST_all_2pt_clusterN_clusterWL_test_fid_"+str(i))
#      13     plt.plot(data[0:12,0],data[0:12,1],lw=2)
# ---> 14 ax.set_yscale("log", nonposy='clip')
#      15 plt.plot
#
# NameError: name 'ax' is not defined
