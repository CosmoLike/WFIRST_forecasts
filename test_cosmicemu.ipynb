# %%
import numpy as np
import matplotlib.pyplot as plt
from matplotlib.colors import LogNorm#, SymLogNorm
# import matplotlib.image as mpimg
import sys
import math
from numpy import linalg as LA

path='/users/timeifler/CosmoLike/WFIRST_forecasts/datav/'
fig=plt.figure(1)
for i in range(100):
    data = np.genfromtxt(path+"WFIRST_all_2pt_clusterN_clusterWL_test_fid_"+str(i))
    plt.semilogy(data[0:12,0],data[0:12,1],lw=2)
    
plt.plot
# Out:
# <function matplotlib.pyplot.plot>
